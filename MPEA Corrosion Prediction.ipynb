# %% [markdown]
# # **MPEA ML** (Run the box below to start the GUI).
#
# - Enter the chemical composition in wt.%.
# - Select one of the available electrolytes.
# - Enter the electrolyte concentrarion in M.
#
# - By pressing **"Run"** button, the predicted values of corrosion current density, corrosion potential and pitting potential will be shown.

# %%
# @title **Press here to start**
#!rm -rf MPEAsAlloyPublic
#from google.colab import drive
#drive.mount('/content/drive')

#!pip install scikit-learn==1.6.1



if 'google.colab' in str(get_ipython()):

    # !git clone https://github.com/katrina-coder/MPEAsAlloyPublic &> /dev/null
    # !pip install scikit-learn==1.1.1 &> /dev/null
    from MPEAsAlloyPublic.optimiserGUI import *
else:
    from optimiserGUI import *

generateModeSelectionGUI()
# Out:
# Dropdown(description='<b>Select Mode:</b>', options=('Corrosion',), style=DescriptionStyle(description_width='…
# ...
# Button(description='Run', style=ButtonStyle())
# start running model ....
# =============== Scan Finished ===============
#
# Al content has been balanced to 70.0 %
#
# Chemical composition:
# Al:70.0  B:0.0  Be:0.0  Co:10.0  Cr:0.0  Cu:0.0  Fe:0.0  Ga:0.0  Hf:0.0  La:0.0
# Mg:10.0  Mn:0.0  Mo:0.0  Nb:0.0  Ni:0.0  Si:10.0  Sn:0.0  Ta:0.0  Ti:0.0  V:0.0
# W:0.0  Y:0.0  Zn:0.0  Zr:0.0
#
# Electrolyte: NaCl
# Microstructure: HCP
# Predicted Current density: 23.12334177163425 microA/cm2
# Predicted Corrosion potential: -359.7130941657869 mV vs. SCE
# Predicted Pitting potential: 477.12462037414497 mV vs. SCE
#
# ...
